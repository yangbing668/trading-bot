# %% [markdown]
# # Visualization: Trading Session

# %%
import pandas as pd
import numpy as np
import altair as alt
import seaborn as sns
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # 指定将要使用的GPU设备

# %% [markdown]
# ### 1. Define parameters and Load model

# %%
from trading_bot.agent import Agent
purchasing_ability = 500
window_size = 12
batch_size = 20
ep_count = 10
model_name = 'GE_w{}_b{}_e{}'.format(window_size, batch_size, ep_count)
test_stock = 'data/test/GE.csv'
debug = True

# %% [markdown]
# ### 2. Load test data

# %%
# read csv into dataframe
df = pd.read_csv(test_stock)
# filter out the desired features
df = df[['date', 'close']]
# rename feature column names
df = df.rename(columns={'close': 'actual', 'date': 'date'})
# convert dates from object to DateTime type
dates = df['date']
dates = pd.to_datetime(dates, infer_datetime_format=True)
df['date'] = dates

df.head()
# Out:
#         date     actual
# 0 2015-01-02  24.096153
# 1 2015-01-05  23.653847
# 2 2015-01-06  23.144230
# 3 2015-01-07  23.153847
# 4 2015-01-08  23.432692

# %% [markdown]
# ### 3. Running Eval

# %%
import logging
import coloredlogs

from trading_bot.utils import show_eval_result, get_stock_data
from trading_bot.methods import evaluate_model, test_model

serviceChargeRate = 0.0
coloredlogs.install(level='DEBUG')

test_data= get_stock_data(test_stock)

agent = Agent(window_size, pretrained=True, model_name=model_name)

profit, history, maxAmount, total_profits = evaluate_model(agent, test_data, window_size, debug, purchasing_ability, serviceChargeRate)
show_eval_result(model_name, profit, maxAmount)
# Out:
# 2022-03-10 14:31:10 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 26.66; bugShare: 200; holdShare: 200; profit: +0.00
# 2022-03-10 14:31:10 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 26.40; bugShare: 200; holdShare: 400; profit: +0.00
# 2022-03-10 14:31:10 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 26.20; bugShare: 100; holdShare: 500; profit: +0.00
# 2022-03-10 14:31:10 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 26.05 | Position: -0.42; sellShare: 200; holdShare: 300; profit: -83.85
# 2022-03-10 14:31:10 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 26.04 | Position: -0.43; sellShare: 100; holdShare: 200; profit: -42.88
# 2022-03-10 14:31:10 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 26.26 | Position: -0.21; sellShare: 100; holdShare: 100; profit: -20.77
# 2022-03-10 14:31:10 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 26.22 | Position: -0.25; sellShare: 100; holdShare: 0; profit: -24.62
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 24.05; bugShare: 200; holdShare: 200; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 24.19 | Position: +0.14; sellShare: 100; holdShare: 100; profit: +14.42
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 23.87; bugShare: 200; holdShare: 300; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 22.96; bugShare: 100; holdShare: 400; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 23.57 | Position: -0.12; sellShare: 100; holdShare: 300; profit: -11.78
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 24.00 | Position: +0.31; sellShare: 100; holdShare: 200; profit: +31.49
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 23.61; bugShare: 100; holdShare: 300; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 23.73; bugShare: 100; holdShare: 400; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 23.99; bugShare: 100; holdShare: 500; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 24.17 | Position: +0.43; sellShare: 200; holdShare: 300; profit: +86.73
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 23.95; bugShare: 100; holdShare: 400; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 23.96; bugShare: 100; holdShare: 500; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 23.38 | Position: -0.45; sellShare: 200; holdShare: 300; profit: -90.27
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 23.62 | Position: -0.20; sellShare: 100; holdShare: 200; profit: -20.13
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 24.25 | Position: +0.42; sellShare: 100; holdShare: 100; profit: +42.37
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 24.22 | Position: +0.39; sellShare: 100; holdShare: 0; profit: +39.48
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 26.70; bugShare: 200; holdShare: 200; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 26.95; bugShare: 200; holdShare: 400; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Buy at: 26.99; bugShare: 100; holdShare: 500; profit: +0.00
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 28.44 | Position: +1.58; sellShare: 200; holdShare: 300; profit: +316.54
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 28.38 | Position: +1.52; sellShare: 100; holdShare: 200; profit: +151.54
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 28.41 | Position: +1.55; sellShare: 100; holdShare: 100; profit: +155.38
# 2022-03-10 14:31:11 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at:
WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 7.28 | Position: -0.08; sellShare: 100; holdShare: 200; profit: -7.50
# 2022-03-10 14:31:15 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 7.15 | Position: -0.21; sellShare: 100; holdShare: 100; profit: -20.50
# 2022-03-10 14:31:15 WIN-3UUV9Q0T2IC root[17260] DEBUG Sell at: 7.04 | Position: -0.32; sellShare: 100; holdShare: 0; profit: -31.50
# 2022-03-10 14:31:15 WIN-3UUV9Q0T2IC root[17260] INFO Model Name:GE_w12_b20_e10.h5: Total Profit:+989.58 Maximum Expenditure:15221.73082

# %% [markdown]
# ### 4. Visualize

# %%
def visualize(df, history, title="trading session"):
    # add history to dataframe
    position = [history[0][0]] + [x[0] for x in history]
    actions = ['HOLD'] + [x[1] for x in history]
    actShares = [0] + [x[2] for x in history]
    df['position'] = position
    df['action'] = actions
    df['actShares'] = actShares
    
    # specify y-axis scale for stock prices
    scale = alt.Scale(domain=(min(min(df['actual']), min(df['position'])), max(max(df['actual']), max(df['position']))), clamp=True)
    
    # plot a line chart for stock positions
    actual = alt.Chart(df).mark_line(
        color='green',
        opacity=0.5
    ).encode(
        x='date:T',
        y=alt.Y('position', axis=alt.Axis(format='$.2f', title='Price'), scale=scale),
    ).interactive(
        bind_y=False
    )
    
    # plot the BUY and SELL actions as points
    points = alt.Chart(df).transform_filter(
        alt.datum.action != 'HOLD'
    ).mark_point(
        filled=True
    ).encode(
        x=alt.X('date:T', axis=alt.Axis(title='Date')),
        y=alt.Y('position', axis=alt.Axis(format='$.2f', title='Price'), scale=scale),
        color='action'
    ).interactive(bind_y=False)
    
    # plot actShares
    text = alt.Chart(df).transform_filter(alt.datum.actShares != 0).mark_text(
        align='left', dx=5, dy=5
    ).encode(
        x=alt.X('date:T', axis=alt.Axis(title='Date')),
        y=alt.Y('position', axis=alt.Axis(format='$.2f', title='Price'), scale=scale),
        color='action',
        text = 'actShares:N',
    ).interactive(bind_y=False)
    

    # merge the two charts
    chart = alt.layer(actual, points, title=title).properties(height=300, width=1000)
    chart = alt.layer(chart, text, title=title).properties(height=300, width=1000)
    
    
    return chart

# %%
chart = visualize(df, history, title=test_stock)
chart
# Out:
# alt.LayerChart(...)

# %%
def visualize_(df, total_profits, title="trading session"):
    # add history to dataframe
    df['total_profits'] = [0] + total_profits
    
    # specify y-axis scale for stock prices
    scale = alt.Scale(domain=(min(df['total_profits']), max(df['total_profits'])), clamp=True)
    
    # plot a line chart for stock positions
    actual = alt.Chart(df).mark_line(
        color='red',
        opacity=0.5
    ).encode(
        x='date:T',
        y=alt.Y('total_profits', axis=alt.Axis(format='$.2f', title='profits'), scale=scale),
    ).interactive(
        bind_y=False
    )
    
    # merge the two charts
    chart = alt.layer(actual, title=title).properties(height=300, width=1000)

    return chart

# %%
chart = visualize_(df, total_profits, title=test_stock)
chart
# Out:
# alt.LayerChart(...)
